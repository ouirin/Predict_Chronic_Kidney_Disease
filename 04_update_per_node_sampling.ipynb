# %%
import numpy as np
import pandas as pd
import xgboost
import sklearn

import matplotlib.pyplot as plt

# %%
# step1：去掉数据不完整的行
df = pd.read_csv("2017.csv").dropna()
# step2：性别、是否吸烟等特征转one-hot
df = pd.get_dummies(df, columns=['sex','SMK_STAT_TYPE_RSPS_CD'])
# step3: 去掉creatinine高于2.5的样本
df = df.loc[(df["CREATININE "]<=2.5)&(df["CREATININE "]>=0.0)]
# step4: 切分训练集与测试集
df_train = df[0:900000]; df_test = df[900000:990112]

# %%
# step5: 训练集与测试集下采样
intervals = [(i * 0.1 + 0.05, i * 0.1 + 0.15) for i in range(25)]

temp_train, temp_test = [], []

for index, (low, high) in enumerate(intervals):
    
    df_sample_train = df_train.loc[(df_train["CREATININE "] > low) & (df_train["CREATININE "] < high)]
    df_sample_test  = df_test.loc[(df_test["CREATININE "] > low) & (df_test["CREATININE "] < high)]
    
    if index in range(3, 14): df_sample_train = df_sample_train.sample(2500)
    if index in range(3, 16): df_sample_test  = df_sample_test.sample(100)
    
    temp_train.append(df_sample_train)
    temp_test.append(df_sample_test)

df_train = pd.concat(temp_train, ignore_index=True)
df_test = pd.concat(temp_test, ignore_index=True)

# step6: 选取特征x与目标y
y_train = df_train["CREATININE "].values.reshape(-1, 1)
x_train = df_train.drop(columns=["id", "sido", "CREATININE ", "GFR", "stage", "height", "weight"]).values

y_test = df_test["CREATININE "].values.reshape(-1, 1)
x_test = df_test.drop(columns=["id", "sido", "CREATININE ", "GFR", "stage", "height", "weight"]).values

# %%
# step7: 使用自定义loss_func训练模型，计算预测值与真实值的R2
mean_value = df["CREATININE "].mean()

weights = [1] * 10

intervals = [0.1 * i * (df['CREATININE '].max() - df['CREATININE '].min()) + df['CREATININE '].min() for i in range(0, 11)]
intervals[10] += 0.001

def custom_loss(true,pred):
    
    error = pred - true
    
    global weights, intervals

    #统计特定区间内误差总和及样本数量，并计算均值
    error_sum, sample_count = [0] * 10, [0] * 10
    
    for i in range(len(true)):
        
        error_abs = abs(true[i] - pred[i])
        
        for j in range(0, len(intervals)-1):
            
            if intervals[j] <= true[i] < intervals[j+1]:
                error_sum[j] += error_abs
                sample_count[j] += 1
                break

    weights = [error_sum[j] / sample_count[j] if sample_count[j] > 0 else 0 for j in range(10)]

    #调整特定区间内样本的梯度
    for i in range(len(true)):
        
        for j in range(0, len(intervals)-1):
            
            if intervals[j] <= true[i] < intervals[j+1]:
                
                error[i] = error[i] * (weights[j] / np.mean(weights)); 
                
                break
                
    grad = error
    
    return grad, np.ones_like(pred)

model = xgboost.XGBRegressor(
            max_depth=10, n_estimators=500, learning_rate=0.05, 
            min_child_weight=100, nthread=4, subsample=1, early_stopping_rounds=10, 
            colsample_bytree=1, reg_alpha=0, reg_lambda=0, gamma=0, 
            eval_metric='rmse', objective=custom_loss, seed=10
        )

model.fit(
    x_train, y_train, verbose=1, 
    eval_set=[(x_train, y_train),(x_test, y_test)],  
)

print("R2指数：",model.score(x_test, y_test))
# Out:
# [0]	validation_0-rmse:0.64568	validation_1-rmse:0.73499
# [1]	validation_0-rmse:0.61834	validation_1-rmse:0.70412
# [2]	validation_0-rmse:0.59290	validation_1-rmse:0.67578
# [3]	validation_0-rmse:0.56923	validation_1-rmse:0.64925
# [4]	validation_0-rmse:0.54730	validation_1-rmse:0.62475
# [5]	validation_0-rmse:0.52691	validation_1-rmse:0.60203
# [6]	validation_0-rmse:0.50807	validation_1-rmse:0.58114
# [7]	validation_0-rmse:0.49063	validation_1-rmse:0.56156
# [8]	validation_0-rmse:0.47452	validation_1-rmse:0.54388
# [9]	validation_0-rmse:0.45955	validation_1-rmse:0.52733
# [10]	validation_0-rmse:0.44574	validation_1-rmse:0.51197
# [11]	validation_0-rmse:0.43300	validation_1-rmse:0.49799
# [12]	validation_0-rmse:0.42123	validation_1-rmse:0.48499
# [13]	validation_0-rmse:0.41039	validation_1-rmse:0.47326
# [14]	validation_0-rmse:0.40041	validation_1-rmse:0.46238
# [15]	validation_0-rmse:0.39124	validation_1-rmse:0.45234
# [16]	validation_0-rmse:0.38278	validation_1-rmse:0.44306
# [17]	validation_0-rmse:0.37507	validation_1-rmse:0.43469
# [18]	validation_0-rmse:0.36791	validation_1-rmse:0.42712
# [19]	validation_0-rmse:0.36137	validation_1-rmse:0.42002
# [20]	validation_0-rmse:0.35538	validation_1-rmse:0.41353
# [21]	validation_0-rmse:0.34989	validation_1-rmse:0.40756
# [22]	validation_0-rmse:0.34485	validation_1-rmse:0.40216
# [23]	validation_0-rmse:0.34025	validation_1-rmse:0.39726
# [24]	validation_0-rmse:0.33604	validation_1-rmse:0.39267
# [25]	validation_0-rmse:0.33218	validation_1-rmse:0.38850
# [26]	validation_0-rmse:0.32866	validation_1-rmse:0.38471
# [27]	validation_0-rmse:0.32542	validation_1-rmse:0.38133
# [28]	validation_0-rmse:0.32244	validation_1-rmse:0.37820
# [29]	validation_0-rmse:0.31968	validation_1-rmse:0.37536
# [30]	validation_0-rmse:0.31718	validation_1-rmse:0.37274
# [31]	validation_0-rmse:0.31484	validation_1-rmse:0.37030
# [32]	validation_0-rmse:0.31266	validation_1-rmse:0.36808
# [33]	validation_0-rmse:0.31062	validation_1-rmse:0.36602
# [34]	validation_0-rmse:0.30878	validation_1-rmse:0.36415
# [35]	validation_0-rmse:0.30711	validation_1-rmse:0.36236
# [36]	validation_0-rmse:0.30549	validation_1-rmse:0.36091
# [37]	validation_0-rmse:0.30403	validation_1-rmse:0.35959
# [38]	validation_0-rmse:0.30271	validation_1-rmse:0.35823
# [39]	validation_0-rmse:0.30146	validation_1-rmse:0.35714
# [40]	validation_0-rmse:0.30024	validation_1-rmse:0.35592
# [41]	validation_0-rmse:0.29920	validation_1-rmse:0.35479
# [42]	validation_0-rmse:0.29821	validation_1-rmse:0.35378
# [43]	validation_0-rmse:0.29729	validation_1-rmse:0.35287
# [44]	validation_0-rmse:0.29648	validation_1-rmse:0.35212
# [45]	validation_0-rmse:0.29566	validation_1-rmse:0.35142
# [46]	validation_0-rmse:0.29487	validation_1-rmse:0.35066
# [47]	validation_0-rmse:0.29416	validation_1-rmse:0.35004
# [48]	validation_0-rmse:0.29355	validation_1-rmse:0.34950
# [49]	validation_0-rmse:0.29295	validation_1-rmse:0.34900
# [50]	validation_0-rmse:0.29238	validation_1-rmse:0.34856
# [51]	validation_0-rmse:0.29179	validation_1-rmse:0.34817
# [52]	validation_0-rmse:0.29130	validation_1-rmse:0.34781
# [53]	validation_0-rmse:0.29085	validation_1-rmse:0.34745
# [54]	validation_0-rmse:0.29044	validation_1-rmse:0.34711
# [55]	validation_0-rmse:0.29009	validation_1-rmse:0.34682
# [56]	validation_0-rmse:0.28958	validation_1-rmse:0.34657
# [57]	validation_0-rmse:0.28919	validation_1-rmse:0.34620
# [58]	validation_0-rmse:0.28879	validation_1-rmse:0.34591
# [59]	validation_0-rmse:0.28836	validation_1-rmse:0.34566
# [60]	validation_0-rmse:0.28807	validation_1-rmse:0.34550
# [61]	validation_0-rmse:0.28776	validation_1-rmse:0.34537
# [62]	validation_0-rmse:0.28743	validation_1-rmse:0.34518
# [63]	validation_0-rmse:0.28708	validation_1-rmse:0.34509
# [64]	validation_0-rmse:0.28676	validation_1-rmse:0.34492
# [65]	validation_0-rmse:0.28649	validation_1-rmse:0.34485
# [66]	validation_0-rmse:0.28614	validation_1-rmse:0.34471
# [67]	validation_0-rmse:0.28589	validation_1-rmse:0.34456
# [68]	validation_0-rmse:0.28564	validation_1-rmse:0.34442
# [69]	validation_0-rmse:0.28533	validation_1-rmse:0.34424
# [70]	validation_0-rmse:0.28512	validation_1-rmse:0.34413
# [71]	validation_0-rmse:0.28493	validation_1-rmse:0.34397
# [72]	validation_0-rmse:0.28464	validation_1-rmse:0.34399
# [73]	validation_0-rmse:0.28437	validation_1-rmse:0.34389
# [74]	validation_0-rmse:0.28410	validation_1-rmse:0.34384
# [75]	validation_0-rmse:0.28384	validation_1-rmse:0.34374
# [76]	validation_0-rmse:0.28366	validation_1-rmse:0.34377
# [77]	validation_0-rmse:0.28348	validation_1-rmse:0.34374
# [78]	validation_0-rmse:0.28315	validation_1-rmse:0.34364
# [79]	validation_0-rmse:0.28293	validation_1-rmse:0.34358
# [80]	validation_0-rmse:0.28268	validation_1-rmse:0.34350
# [81]	validation_0-rmse:0.28243	validation_1-rmse:0.34341
# [82]	validation_0-rmse:0.28215	validation_1-rmse:0.34327
# [83]	validation_0-rmse:0.28190	validation_1-rmse:0.34318
# [84]	validation_0-rmse:0.28170	validation_1-rmse:0.34313
# [85]	validation_0-rmse:0.28148	validation_1-rmse:0.34312
# [86]	validation_0-rmse:0.28131	validation_1-rmse:0.34302
# [87]	validation_0-rmse:0.28113	validation_1-rmse:0.34301
# [88]	validation_0-rmse:0.28097	validation_1-rmse:0.34297
# [89]	validation_0-rmse:0.28080	validation_1-rmse:0.34285
# [90]	validation_0-rmse:0.28063	validation_1-rmse:0.34279
# [91]	validation_0-rmse:0.28051	validation_1-rmse:0.34279
# [92]	validation_0-rmse:0.28033	validation_1-rmse:0.34281
# [93]	validation_0-rmse:0.28023	validation_1-rmse:0.34275
# [94]	validation_0-rmse:0.28003	validation_1-rmse:0.34269
# [95]	validation_0-rmse:0.27988	validation_1-rmse:0.34272
# [96]	validation_0-rmse:0.27975	validation_1-rmse:0.34271
# [97]	validation_0-rmse:0.27960	validation_1-rmse:0.34272
# [98]	validation_0-rmse:0.27949	validation_1-rmse:0.34274
# [99]	validation_0-rmse:0.27944	validation_1-rmse:0.34275
# [100]	validation_0-rmse:0.27931	validation_1-rmse:0.34276
# [101]	validation_0-rmse:0.27923	validation_1-rmse:0.34276
# [102]	validation_0-rmse:0.27901	validation_1-rmse:0.34274
# [103]	validation_0-rmse:0.27890	validation_1-rmse:0.34270
# R2指数： 0.541720998914125
