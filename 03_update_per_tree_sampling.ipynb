# %%
import numpy as np
import pandas as pd
import xgboost
import sklearn

import matplotlib.pyplot as plt

# %%
# step1：去掉数据不完整的行
df = pd.read_csv("2017.csv").dropna()
# step2：性别、是否吸烟等特征转one-hot
df = pd.get_dummies(df, columns=['sex','SMK_STAT_TYPE_RSPS_CD'])
# step3: 去掉creatinine高于2.5的样本
df = df.loc[(df["CREATININE "]<=2.5)&(df["CREATININE "]>=0.0)]
# step4: 切分训练集与测试集
df_train = df[0:900000]; df_test = df[900000:990112]

# %%
# step5: 训练集与测试集下采样
intervals = [(i * 0.1 + 0.05, i * 0.1 + 0.15) for i in range(25)]

temp_train, temp_test = [], []

for index, (low, high) in enumerate(intervals):
    
    df_sample_train = df_train.loc[(df_train["CREATININE "] > low) & (df_train["CREATININE "] < high)]
    df_sample_test  = df_test.loc[(df_test["CREATININE "] > low) & (df_test["CREATININE "] < high)]
    
    if index in range(3, 14): df_sample_train = df_sample_train.sample(2500)
    if index in range(3, 16): df_sample_test  = df_sample_test.sample(100)
    
    temp_train.append(df_sample_train)
    temp_test.append(df_sample_test)

df_train = pd.concat(temp_train, ignore_index=True)
df_test = pd.concat(temp_test, ignore_index=True)

# step6: 选取特征x与目标y
y_train = df_train["CREATININE "].values.reshape(-1, 1)
x_train = df_train.drop(columns=["id", "sido", "CREATININE ", "GFR", "stage", "height", "weight"]).values

y_test = df_test["CREATININE "].values.reshape(-1, 1)
x_test = df_test.drop(columns=["id", "sido", "CREATININE ", "GFR", "stage", "height", "weight"]).values

# %%
# step7: 使用自定义loss_func与自定义eval_metric训练模型，，计算预测值与真实值的R2
mean_value = df["CREATININE "].mean()

weights = [1] * 10

intervals = [0.1 * i * (df['CREATININE '].max() - df['CREATININE '].min()) + df['CREATININE '].min() for i in range(0, 11)]
intervals[10] += 0.001

def custom_loss(true,pred):
    
    error = pred - true
    
    global weights, intervals
    
    for i in range(len(true)):
        
        for j in range(0, len(intervals)-1):
            
            if intervals[j] <= true[i] < intervals[j+1]:
                
                error[i] = error[i] * (weights[j] / np.mean(weights))
                
                break
                
    grad = error
    
    return grad, np.ones_like(pred)

def custom_eval(true, pred):

    error_sum, sample_count = [0] * 10, [0] * 10
    
    global weights, intervals

    for i in range(len(true)):
        
        error_abs = abs(true[i] - pred[i])
        
        for j in range(0, len(intervals)-1):
            
            if intervals[j] <= true[i] < intervals[j+1]:
                error_sum[j] += error_abs
                sample_count[j] += 1
                break

    weights = [error_sum[j] / sample_count[j] if sample_count[j] > 0 else 0 for j in range(10)]
    
    return np.mean(abs(pred-true))

model = xgboost.XGBRegressor(
            max_depth=10, n_estimators=500, learning_rate=0.05, base_score = mean_value,
            min_child_weight=100, nthread=4, subsample=1, early_stopping_rounds=10, 
            colsample_bytree=1, reg_alpha=0, reg_lambda=0, gamma=0, 
            eval_metric=custom_eval, objective=custom_loss,seed=10
        )

model.fit(
    x_train, y_train, verbose=1, 
    eval_set=[(x_train, y_train),(x_test, y_test)],  
    
)

print("R2指数：",model.score(x_test, y_test))
# Out:
# [0]	validation_0-rmse:0.45574	validation_0-custom_eval:0.36836	validation_1-rmse:0.53903	validation_1-custom_eval:0.43711
# [1]	validation_0-rmse:0.44288	validation_0-custom_eval:0.35816	validation_1-rmse:0.52274	validation_1-custom_eval:0.42431
# [2]	validation_0-rmse:0.43100	validation_0-custom_eval:0.34859	validation_1-rmse:0.50792	validation_1-custom_eval:0.41235
# [3]	validation_0-rmse:0.41995	validation_0-custom_eval:0.33953	validation_1-rmse:0.49397	validation_1-custom_eval:0.40076
# [4]	validation_0-rmse:0.40981	validation_0-custom_eval:0.33108	validation_1-rmse:0.48139	validation_1-custom_eval:0.39035
# [5]	validation_0-rmse:0.40032	validation_0-custom_eval:0.32310	validation_1-rmse:0.46986	validation_1-custom_eval:0.38055
# [6]	validation_0-rmse:0.39157	validation_0-custom_eval:0.31562	validation_1-rmse:0.45898	validation_1-custom_eval:0.37128
# [7]	validation_0-rmse:0.38354	validation_0-custom_eval:0.30871	validation_1-rmse:0.44918	validation_1-custom_eval:0.36284
# [8]	validation_0-rmse:0.37612	validation_0-custom_eval:0.30234	validation_1-rmse:0.44005	validation_1-custom_eval:0.35493
# [9]	validation_0-rmse:0.36932	validation_0-custom_eval:0.29643	validation_1-rmse:0.43188	validation_1-custom_eval:0.34786
# [10]	validation_0-rmse:0.36301	validation_0-custom_eval:0.29088	validation_1-rmse:0.42441	validation_1-custom_eval:0.34123
# [11]	validation_0-rmse:0.35724	validation_0-custom_eval:0.28574	validation_1-rmse:0.41737	validation_1-custom_eval:0.33487
# [12]	validation_0-rmse:0.35188	validation_0-custom_eval:0.28090	validation_1-rmse:0.41090	validation_1-custom_eval:0.32899
# [13]	validation_0-rmse:0.34698	validation_0-custom_eval:0.27640	validation_1-rmse:0.40493	validation_1-custom_eval:0.32334
# [14]	validation_0-rmse:0.34249	validation_0-custom_eval:0.27220	validation_1-rmse:0.39940	validation_1-custom_eval:0.31803
# [15]	validation_0-rmse:0.33829	validation_0-custom_eval:0.26821	validation_1-rmse:0.39435	validation_1-custom_eval:0.31312
# [16]	validation_0-rmse:0.33441	validation_0-custom_eval:0.26447	validation_1-rmse:0.38962	validation_1-custom_eval:0.30845
# [17]	validation_0-rmse:0.33085	validation_0-custom_eval:0.26098	validation_1-rmse:0.38543	validation_1-custom_eval:0.30423
# [18]	validation_0-rmse:0.32757	validation_0-custom_eval:0.25771	validation_1-rmse:0.38162	validation_1-custom_eval:0.30027
# [19]	validation_0-rmse:0.32453	validation_0-custom_eval:0.25466	validation_1-rmse:0.37814	validation_1-custom_eval:0.29658
# [20]	validation_0-rmse:0.32175	validation_0-custom_eval:0.25179	validation_1-rmse:0.37484	validation_1-custom_eval:0.29310
# [21]	validation_0-rmse:0.31920	validation_0-custom_eval:0.24910	validation_1-rmse:0.37199	validation_1-custom_eval:0.28992
# [22]	validation_0-rmse:0.31679	validation_0-custom_eval:0.24659	validation_1-rmse:0.36907	validation_1-custom_eval:0.28670
# [23]	validation_0-rmse:0.31459	validation_0-custom_eval:0.24423	validation_1-rmse:0.36652	validation_1-custom_eval:0.28381
# [24]	validation_0-rmse:0.31257	validation_0-custom_eval:0.24205	validation_1-rmse:0.36419	validation_1-custom_eval:0.28119
# [25]	validation_0-rmse:0.31068	validation_0-custom_eval:0.24001	validation_1-rmse:0.36200	validation_1-custom_eval:0.27879
# [26]	validation_0-rmse:0.30895	validation_0-custom_eval:0.23815	validation_1-rmse:0.36010	validation_1-custom_eval:0.27658
# [27]	validation_0-rmse:0.30728	validation_0-custom_eval:0.23642	validation_1-rmse:0.35824	validation_1-custom_eval:0.27449
# [28]	validation_0-rmse:0.30578	validation_0-custom_eval:0.23485	validation_1-rmse:0.35657	validation_1-custom_eval:0.27259
# [29]	validation_0-rmse:0.30442	validation_0-custom_eval:0.23340	validation_1-rmse:0.35499	validation_1-custom_eval:0.27078
# [30]	validation_0-rmse:0.30318	validation_0-custom_eval:0.23209	validation_1-rmse:0.35365	validation_1-custom_eval:0.26922
# [31]	validation_0-rmse:0.30200	validation_0-custom_eval:0.23086	validation_1-rmse:0.35236	validation_1-custom_eval:0.26772
# [32]	validation_0-rmse:0.30091	validation_0-custom_eval:0.22971	validation_1-rmse:0.35104	validation_1-custom_eval:0.26631
# [33]	validation_0-rmse:0.29986	validation_0-custom_eval:0.22864	validation_1-rmse:0.34987	validation_1-custom_eval:0.26493
# [34]	validation_0-rmse:0.29892	validation_0-custom_eval:0.22766	validation_1-rmse:0.34880	validation_1-custom_eval:0.26368
# [35]	validation_0-rmse:0.29795	validation_0-custom_eval:0.22671	validation_1-rmse:0.34793	validation_1-custom_eval:0.26263
# [36]	validation_0-rmse:0.29709	validation_0-custom_eval:0.22583	validation_1-rmse:0.34711	validation_1-custom_eval:0.26166
# [37]	validation_0-rmse:0.29629	validation_0-custom_eval:0.22501	validation_1-rmse:0.34624	validation_1-custom_eval:0.26060
# [38]	validation_0-rmse:0.29552	validation_0-custom_eval:0.22422	validation_1-rmse:0.34559	validation_1-custom_eval:0.25979
# [39]	validation_0-rmse:0.29486	validation_0-custom_eval:0.22351	validation_1-rmse:0.34497	validation_1-custom_eval:0.25901
# [40]	validation_0-rmse:0.29418	validation_0-custom_eval:0.22282	validation_1-rmse:0.34427	validation_1-custom_eval:0.25830
# [41]	validation_0-rmse:0.29353	validation_0-custom_eval:0.22216	validation_1-rmse:0.34362	validation_1-custom_eval:0.25749
# [42]	validation_0-rmse:0.29292	validation_0-custom_eval:0.22151	validation_1-rmse:0.34295	validation_1-custom_eval:0.25677
# [43]	validation_0-rmse:0.29234	validation_0-custom_eval:0.22090	validation_1-rmse:0.34231	validation_1-custom_eval:0.25605
# [44]	validation_0-rmse:0.29174	validation_0-custom_eval:0.22031	validation_1-rmse:0.34176	validation_1-custom_eval:0.25540
# [45]	validation_0-rmse:0.29125	validation_0-custom_eval:0.21979	validation_1-rmse:0.34131	validation_1-custom_eval:0.25486
# [46]	validation_0-rmse:0.29072	validation_0-custom_eval:0.21925	validation_1-rmse:0.34095	validation_1-custom_eval:0.25444
# [47]	validation_0-rmse:0.29026	validation_0-custom_eval:0.21875	validation_1-rmse:0.34051	validation_1-custom_eval:0.25397
# [48]	validation_0-rmse:0.28980	validation_0-custom_eval:0.21827	validation_1-rmse:0.34017	validation_1-custom_eval:0.25358
# [49]	validation_0-rmse:0.28941	validation_0-custom_eval:0.21784	validation_1-rmse:0.33988	validation_1-custom_eval:0.25318
# [50]	validation_0-rmse:0.28902	validation_0-custom_eval:0.21742	validation_1-rmse:0.33955	validation_1-custom_eval:0.25273
# [51]	validation_0-rmse:0.28860	validation_0-custom_eval:0.21698	validation_1-rmse:0.33930	validation_1-custom_eval:0.25238
# [52]	validation_0-rmse:0.28822	validation_0-custom_eval:0.21657	validation_1-rmse:0.33912	validation_1-custom_eval:0.25221
# [53]	validation_0-rmse:0.28789	validation_0-custom_eval:0.21622	validation_1-rmse:0.33887	validation_1-custom_eval:0.25191
# [54]	validation_0-rmse:0.28753	validation_0-custom_eval:0.21586	validation_1-rmse:0.33866	validation_1-custom_eval:0.25163
# [55]	validation_0-rmse:0.28725	validation_0-custom_eval:0.21557	validation_1-rmse:0.33842	validation_1-custom_eval:0.25137
# [56]	validation_0-rmse:0.28701	validation_0-custom_eval:0.21531	validation_1-rmse:0.33827	validation_1-custom_eval:0.25116
# [57]	validation_0-rmse:0.28675	validation_0-custom_eval:0.21504	validation_1-rmse:0.33809	validation_1-custom_eval:0.25093
# [58]	validation_0-rmse:0.28650	validation_0-custom_eval:0.21478	validation_1-rmse:0.33788	validation_1-custom_eval:0.25070
# [59]	validation_0-rmse:0.28627	validation_0-custom_eval:0.21454	validation_1-rmse:0.33774	validation_1-custom_eval:0.25051
# [60]	validation_0-rmse:0.28609	validation_0-custom_eval:0.21431	validation_1-rmse:0.33760	validation_1-custom_eval:0.25033
# [61]	validation_0-rmse:0.28582	validation_0-custom_eval:0.21405	validation_1-rmse:0.33749	validation_1-custom_eval:0.25018
# [62]	validation_0-rmse:0.28561	validation_0-custom_eval:0.21382	validation_1-rmse:0.33737	validation_1-custom_eval:0.24999
# [63]	validation_0-rmse:0.28537	validation_0-custom_eval:0.21360	validation_1-rmse:0.33730	validation_1-custom_eval:0.24982
# [64]	validation_0-rmse:0.28514	validation_0-custom_eval:0.21338	validation_1-rmse:0.33716	validation_1-custom_eval:0.24965
# [65]	validation_0-rmse:0.28492	validation_0-custom_eval:0.21317	validation_1-rmse:0.33706	validation_1-custom_eval:0.24953
# [66]	validation_0-rmse:0.28470	validation_0-custom_eval:0.21298	validation_1-rmse:0.33700	validation_1-custom_eval:0.24943
# [67]	validation_0-rmse:0.28451	validation_0-custom_eval:0.21280	validation_1-rmse:0.33684	validation_1-custom_eval:0.24929
# [68]	validation_0-rmse:0.28434	validation_0-custom_eval:0.21262	validation_1-rmse:0.33684	validation_1-custom_eval:0.24922
# [69]	validation_0-rmse:0.28417	validation_0-custom_eval:0.21246	validation_1-rmse:0.33681	validation_1-custom_eval:0.24910
# [70]	validation_0-rmse:0.28396	validation_0-custom_eval:0.21229	validation_1-rmse:0.33670	validation_1-custom_eval:0.24896
# [71]	validation_0-rmse:0.28379	validation_0-custom_eval:0.21214	validation_1-rmse:0.33672	validation_1-custom_eval:0.24891
# [72]	validation_0-rmse:0.28358	validation_0-custom_eval:0.21195	validation_1-rmse:0.33666	validation_1-custom_eval:0.24883
# [73]	validation_0-rmse:0.28342	validation_0-custom_eval:0.21180	validation_1-rmse:0.33664	validation_1-custom_eval:0.24880
# [74]	validation_0-rmse:0.28314	validation_0-custom_eval:0.21160	validation_1-rmse:0.33667	validation_1-custom_eval:0.24877
# [75]	validation_0-rmse:0.28297	validation_0-custom_eval:0.21146	validation_1-rmse:0.33668	validation_1-custom_eval:0.24874
# [76]	validation_0-rmse:0.28283	validation_0-custom_eval:0.21133	validation_1-rmse:0.33673	validation_1-custom_eval:0.24875
# [77]	validation_0-rmse:0.28273	validation_0-custom_eval:0.21124	validation_1-rmse:0.33673	validation_1-custom_eval:0.24867
# [78]	validation_0-rmse:0.28254	validation_0-custom_eval:0.21109	validation_1-rmse:0.33673	validation_1-custom_eval:0.24862
# [79]	validation_0-rmse:0.28238	validation_0-custom_eval:0.21097	validation_1-rmse:0.33674	validation_1-custom_eval:0.24859
# [80]	validation_0-rmse:0.28224	validation_0-custom_eval:0.21085	validation_1-rmse:0.33678	validation_1-custom_eval:0.24859
# [81]	validation_0-rmse:0.28213	validation_0-custom_eval:0.21076	validation_1-rmse:0.33682	validation_1-custom_eval:0.24860
# [82]	validation_0-rmse:0.28200	validation_0-custom_eval:0.21066	validation_1-rmse:0.33683	validation_1-custom_eval:0.24859
# [83]	validation_0-rmse:0.28180	validation_0-custom_eval:0.21052	validation_1-rmse:0.33688	validation_1-custom_eval:0.24861
# [84]	validation_0-rmse:0.28166	validation_0-custom_eval:0.21041	validation_1-rmse:0.33683	validation_1-custom_eval:0.24853
# [85]	validation_0-rmse:0.28142	validation_0-custom_eval:0.21024	validation_1-rmse:0.33671	validation_1-custom_eval:0.24839
# [86]	validation_0-rmse:0.28126	validation_0-custom_eval:0.21013	validation_1-rmse:0.33660	validation_1-custom_eval:0.24825
# [87]	validation_0-rmse:0.28108	validation_0-custom_eval:0.20999	validation_1-rmse:0.33669	validation_1-custom_eval:0.24832
# [88]	validation_0-rmse:0.28089	validation_0-custom_eval:0.20985	validation_1-rmse:0.33669	validation_1-custom_eval:0.24832
# [89]	validation_0-rmse:0.28081	validation_0-custom_eval:0.20978	validation_1-rmse:0.33671	validation_1-custom_eval:0.24833
# [90]	validation_0-rmse:0.28061	validation_0-custom_eval:0.20965	validation_1-rmse:0.33674	validation_1-custom_eval:0.24836
# [91]	validation_0-rmse:0.28048	validation_0-custom_eval:0.20955	validation_1-rmse:0.33670	validation_1-custom_eval:0.24832
# [92]	validation_0-rmse:0.28023	validation_0-custom_eval:0.20939	validation_1-rmse:0.33673	validation_1-custom_eval:0.24824
# [93]	validation_0-rmse:0.28000	validation_0-custom_eval:0.20924	validation_1-rmse:0.33668	validation_1-custom_eval:0.24814
# [94]	validation_0-rmse:0.27979	validation_0-custom_eval:0.20910	validation_1-rmse:0.33669	validation_1-custom_eval:0.24807
# [95]	validation_0-rmse:0.27958	validation_0-custom_eval:0.20897	validation_1-rmse:0.33670	validation_1-custom_eval:0.24802
# [96]	validation_0-rmse:0.27943	validation_0-custom_eval:0.20887	validation_1-rmse:0.33676	validation_1-custom_eval:0.24805
# [97]	validation_0-rmse:0.27924	validation_0-custom_eval:0.20874	validation_1-rmse:0.33669	validation_1-custom_eval:0.24795
# [98]	validation_0-rmse:0.27903	validation_0-custom_eval:0.20861	validation_1-rmse:0.33661	validation_1-custom_eval:0.24788
# [99]	validation_0-rmse:0.27893	validation_0-custom_eval:0.20855	validation_1-rmse:0.33668	validation_1-custom_eval:0.24786
# [100]	validation_0-rmse:0.27885	validation_0-custom_eval:0.20849	validation_1-rmse:0.33667	validation_1-custom_eval:0.24787
# [101]	validation_0-rmse:0.27878	validation_0-custom_eval:0.20845	validation_1-rmse:0.33674	validation_1-custom_eval:0.24788
# [102]	validation_0-rmse:0.27867	validation_0-custom_eval:0.20837	validation_1-rmse:0.33671	validation_1-custom_eval:0.24782
# [103]	validation_0-rmse:0.27861	validation_0-custom_eval:0.20833	validation_1-rmse:0.33673	validation_1-custom_eval:0.24785
# [104]	validation_0-rmse:0.27848	validation_0-custom_eval:0.20826	validation_1-rmse:0.33670	validation_1-custom_eval:0.24781
# [105]	validation_0-rmse:0.27837	validation_0-custom_eval:0.20819	validation_1-rmse:0.33677	validation_1-custom_eval:0.24783
# [106]	validation_0-rmse:0.27821	validation_0-custom_eval:0.20810	validation_1-rmse:0.33672	validation_1-custom_eval:0.24780
# [107]	validation_0-rmse:0.27815	validation_0-custom_eval:0.20806	validation_1-rmse:0.33670	validation_1-custom_eval:0.24777
# [108]	validation_0-rmse:0.27811	validation_0-custom_eval:0.20804	validation_1-rmse:0.33670	validation_1-custom_eval:0.24774
# [109]	validation_0-rmse:0.27793	validation_0-custom_eval:0.20793	validation_1-rmse:0.33668	validation_1-custom_eval:0.24769
# [110]	validation_0-rmse:0.27785	validation_0-custom_eval:0.20788	validation_1-rmse:0.33674	validation_1-custom_eval:0.24773
# [111]	validation_0-rmse:0.27769	validation_0-custom_eval:0.20778	validation_1-rmse:0.33676	validation_1-custom_eval:0.24770
# [112]	validation_0-rmse:0.27761	validation_0-custom_eval:0.20773	validation_1-rmse:0.33685	validation_1-custom_eval:0.24775
# [113]	validation_0-rmse:0.27741	validation_0-custom_eval:0.20761	validation_1-rmse:0.33684	validation_1-custom_eval:0.24768
# [114]	validation_0-rmse:0.27724	validation_0-custom_eval:0.20751	validation_1-rmse:0.33688	validation_1-custom_eval:0.24772
# [115]	validation_0-rmse:0.27719	validation_0-custom_eval:0.20748	validation_1-rmse:0.33693	validation_1-custom_eval:0.24774
# [116]	validation_0-rmse:0.27703	validation_0-custom_eval:0.20738	validation_1-rmse:0.33694	validation_1-custom_eval:0.24775
# [117]	validation_0-rmse:0.27690	validation_0-custom_eval:0.20730	validation_1-rmse:0.33701	validation_1-custom_eval:0.24777
# [118]	validation_0-rmse:0.27684	validation_0-custom_eval:0.20727	validation_1-rmse:0.33703	validation_1-custom_eval:0.24777
# [119]	validation_0-rmse:0.27662	validation_0-custom_eval:0.20715	validation_1-rmse:0.33707	validation_1-custom_eval:0.24777
# [120]	validation_0-rmse:0.27654	validation_0-custom_eval:0.20710	validation_1-rmse:0.33707	validation_1-custom_eval:0.24776
# [121]	validation_0-rmse:0.27644	validation_0-custom_eval:0.20704	validation_1-rmse:0.33706	validation_1-custom_eval:0.24778
# [122]	validation_0-rmse:0.27635	validation_0-custom_eval:0.20698	validation_1-rmse:0.33708	validation_1-custom_eval:0.24779
# R2指数： 0.5572483591470996
