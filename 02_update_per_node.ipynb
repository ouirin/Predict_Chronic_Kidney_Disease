# %%
import numpy as np
import pandas as pd
import xgboost
import sklearn

import matplotlib.pyplot as plt

# %%
# step1：去掉数据不完整的行
df = pd.read_csv("2017.csv").dropna()
# step2：性别、是否吸烟等特征转one-hot
df = pd.get_dummies(df, columns=['sex','SMK_STAT_TYPE_RSPS_CD'])
# step3: 去掉creatinine高于2.5的样本
df = df.loc[(df["CREATININE "]<=2.5)&(df["CREATININE "]>=0.0)]
# step4: 切分训练集与测试集
df_train = df[0:900000]; df_test = df[900000:990112] 
# step5: 选取特征x与目标y
y_train = df_train["CREATININE "].values.reshape(-1, 1)
x_train = df_train.drop(columns=["id", "sido", "CREATININE ", "GFR", "stage", "height", "weight"]).values
y_test = df_test["CREATININE "].values.reshape(-1, 1)
x_test = df_test.drop(columns=["id", "sido", "CREATININE ", "GFR", "stage", "height", "weight"]).values

# %%
# step6: 使用自定义loss_func训练模型，计算预测值与真实值的R2
mean_value = df["CREATININE "].mean()

weights = [1] * 10

intervals = [0.1 * i * (df['CREATININE '].max() - df['CREATININE '].min()) + df['CREATININE '].min() for i in range(0, 11)]
intervals[10] += 0.001

def custom_loss(true,pred):
    
    error = pred - true
    
    global weights, intervals

    #统计特定区间内误差总和及样本数量，并计算均值
    error_sum, sample_count = [0] * 10, [0] * 10
    
    for i in range(len(true)):
        
        error_abs = abs(true[i] - pred[i])
        
        for j in range(0, len(intervals)-1):
            
            if intervals[j] <= true[i] < intervals[j+1]:
                error_sum[j] += error_abs
                sample_count[j] += 1
                break

    weights = [error_sum[j] / sample_count[j] if sample_count[j] > 0 else 0 for j in range(10)]

    #调整特定区间内样本的梯度
    for i in range(len(true)):
        
        for j in range(0, len(intervals)-1):
            
            if intervals[j] <= true[i] < intervals[j+1]:
                
                error[i] = error[i] * (weights[j] / np.mean(weights)); 
                
                break
                
    grad = error
    
    return grad, np.ones_like(pred)

model = xgboost.XGBRegressor(
            max_depth=10, n_estimators=500, learning_rate=0.05, base_score = mean_value,
            min_child_weight=100, nthread=4, subsample=1, early_stopping_rounds=10, 
            colsample_bytree=1, reg_alpha=0, reg_lambda=0, gamma=0, 
            eval_metric='rmse', objective=custom_loss, seed=10
        )

model.fit(
    x_train, y_train, verbose=1, 
    eval_set=[(x_train, y_train),(x_test, y_test)],  
)

print("R2指数：",model.score(x_test, y_test))
# Out:
# [0]	validation_0-rmse:0.20213	validation_1-rmse:0.20039
# [1]	validation_0-rmse:0.20067	validation_1-rmse:0.19896
# [2]	validation_0-rmse:0.19926	validation_1-rmse:0.19757
# [3]	validation_0-rmse:0.19790	validation_1-rmse:0.19623
# [4]	validation_0-rmse:0.19658	validation_1-rmse:0.19493
# [5]	validation_0-rmse:0.19530	validation_1-rmse:0.19367
# [6]	validation_0-rmse:0.19407	validation_1-rmse:0.19246
# [7]	validation_0-rmse:0.19287	validation_1-rmse:0.19129
# [8]	validation_0-rmse:0.19171	validation_1-rmse:0.19015
# [9]	validation_0-rmse:0.19059	validation_1-rmse:0.18905
# [10]	validation_0-rmse:0.18950	validation_1-rmse:0.18799
# [11]	validation_0-rmse:0.18844	validation_1-rmse:0.18696
# [12]	validation_0-rmse:0.18742	validation_1-rmse:0.18597
# [13]	validation_0-rmse:0.18643	validation_1-rmse:0.18501
# [14]	validation_0-rmse:0.18547	validation_1-rmse:0.18407
# [15]	validation_0-rmse:0.18454	validation_1-rmse:0.18317
# [16]	validation_0-rmse:0.18363	validation_1-rmse:0.18230
# [17]	validation_0-rmse:0.18276	validation_1-rmse:0.18144
# [18]	validation_0-rmse:0.18191	validation_1-rmse:0.18063
# [19]	validation_0-rmse:0.18110	validation_1-rmse:0.17983
# [20]	validation_0-rmse:0.18031	validation_1-rmse:0.17907
# [21]	validation_0-rmse:0.17954	validation_1-rmse:0.17833
# [22]	validation_0-rmse:0.17880	validation_1-rmse:0.17761
# [23]	validation_0-rmse:0.17808	validation_1-rmse:0.17692
# [24]	validation_0-rmse:0.17739	validation_1-rmse:0.17626
# [25]	validation_0-rmse:0.17672	validation_1-rmse:0.17562
# [26]	validation_0-rmse:0.17608	validation_1-rmse:0.17500
# [27]	validation_0-rmse:0.17545	validation_1-rmse:0.17441
# [28]	validation_0-rmse:0.17485	validation_1-rmse:0.17383
# [29]	validation_0-rmse:0.17427	validation_1-rmse:0.17328
# [30]	validation_0-rmse:0.17370	validation_1-rmse:0.17274
# [31]	validation_0-rmse:0.17315	validation_1-rmse:0.17223
# [32]	validation_0-rmse:0.17263	validation_1-rmse:0.17174
# [33]	validation_0-rmse:0.17213	validation_1-rmse:0.17126
# [34]	validation_0-rmse:0.17164	validation_1-rmse:0.17080
# [35]	validation_0-rmse:0.17117	validation_1-rmse:0.17035
# [36]	validation_0-rmse:0.17071	validation_1-rmse:0.16991
# [37]	validation_0-rmse:0.17028	validation_1-rmse:0.16950
# [38]	validation_0-rmse:0.16986	validation_1-rmse:0.16911
# [39]	validation_0-rmse:0.16946	validation_1-rmse:0.16873
# [40]	validation_0-rmse:0.16907	validation_1-rmse:0.16836
# [41]	validation_0-rmse:0.16870	validation_1-rmse:0.16801
# [42]	validation_0-rmse:0.16833	validation_1-rmse:0.16768
# [43]	validation_0-rmse:0.16799	validation_1-rmse:0.16736
# [44]	validation_0-rmse:0.16765	validation_1-rmse:0.16705
# [45]	validation_0-rmse:0.16733	validation_1-rmse:0.16675
# [46]	validation_0-rmse:0.16702	validation_1-rmse:0.16647
# [47]	validation_0-rmse:0.16673	validation_1-rmse:0.16620
# [48]	validation_0-rmse:0.16644	validation_1-rmse:0.16593
# [49]	validation_0-rmse:0.16617	validation_1-rmse:0.16568
# [50]	validation_0-rmse:0.16591	validation_1-rmse:0.16545
# [51]	validation_0-rmse:0.16566	validation_1-rmse:0.16522
# [52]	validation_0-rmse:0.16542	validation_1-rmse:0.16500
# [53]	validation_0-rmse:0.16519	validation_1-rmse:0.16479
# [54]	validation_0-rmse:0.16496	validation_1-rmse:0.16459
# [55]	validation_0-rmse:0.16475	validation_1-rmse:0.16440
# [56]	validation_0-rmse:0.16455	validation_1-rmse:0.16423
# [57]	validation_0-rmse:0.16436	validation_1-rmse:0.16406
# [58]	validation_0-rmse:0.16417	validation_1-rmse:0.16390
# [59]	validation_0-rmse:0.16399	validation_1-rmse:0.16374
# [60]	validation_0-rmse:0.16382	validation_1-rmse:0.16360
# [61]	validation_0-rmse:0.16365	validation_1-rmse:0.16346
# [62]	validation_0-rmse:0.16350	validation_1-rmse:0.16332
# [63]	validation_0-rmse:0.16335	validation_1-rmse:0.16320
# [64]	validation_0-rmse:0.16321	validation_1-rmse:0.16308
# [65]	validation_0-rmse:0.16308	validation_1-rmse:0.16297
# [66]	validation_0-rmse:0.16295	validation_1-rmse:0.16286
# [67]	validation_0-rmse:0.16283	validation_1-rmse:0.16277
# [68]	validation_0-rmse:0.16272	validation_1-rmse:0.16268
# [69]	validation_0-rmse:0.16261	validation_1-rmse:0.16260
# [70]	validation_0-rmse:0.16250	validation_1-rmse:0.16252
# [71]	validation_0-rmse:0.16241	validation_1-rmse:0.16244
# [72]	validation_0-rmse:0.16231	validation_1-rmse:0.16237
# [73]	validation_0-rmse:0.16222	validation_1-rmse:0.16230
# [74]	validation_0-rmse:0.16214	validation_1-rmse:0.16224
# [75]	validation_0-rmse:0.16206	validation_1-rmse:0.16218
# [76]	validation_0-rmse:0.16198	validation_1-rmse:0.16212
# [77]	validation_0-rmse:0.16191	validation_1-rmse:0.16207
# [78]	validation_0-rmse:0.16184	validation_1-rmse:0.16202
# [79]	validation_0-rmse:0.16177	validation_1-rmse:0.16198
# [80]	validation_0-rmse:0.16171	validation_1-rmse:0.16194
# [81]	validation_0-rmse:0.16165	validation_1-rmse:0.16191
# [82]	validation_0-rmse:0.16160	validation_1-rmse:0.16187
# [83]	validation_0-rmse:0.16155	validation_1-rmse:0.16184
# [84]	validation_0-rmse:0.16150	validation_1-rmse:0.16181
# [85]	validation_0-rmse:0.16146	validation_1-rmse:0.16178
# [86]	validation_0-rmse:0.16141	validation_1-rmse:0.16176
# [87]	validation_0-rmse:0.16137	validation_1-rmse:0.16174
# [88]	validation_0-rmse:0.16134	validation_1-rmse:0.16172
# [89]	validation_0-rmse:0.16131	validation_1-rmse:0.16171
# [90]	validation_0-rmse:0.16128	validation_1-rmse:0.16169
# [91]	validation_0-rmse:0.16125	validation_1-rmse:0.16168
# [92]	validation_0-rmse:0.16122	validation_1-rmse:0.16167
# [93]	validation_0-rmse:0.16119	validation_1-rmse:0.16166
# [94]	validation_0-rmse:0.16117	validation_1-rmse:0.16166
# [95]	validation_0-rmse:0.16115	validation_1-rmse:0.16166
# [96]	validation_0-rmse:0.16113	validation_1-rmse:0.16166
# [97]	validation_0-rmse:0.16111	validation_1-rmse:0.16166
# [98]	validation_0-rmse:0.16110	validation_1-rmse:0.16166
# [99]	validation_0-rmse:0.16108	validation_1-rmse:0.16166
# [100]	validation_0-rmse:0.16107	validation_1-rmse:0.16167
# [101]	validation_0-rmse:0.16106	validation_1-rmse:0.16167
# [102]	validation_0-rmse:0.16105	validation_1-rmse:0.16168
# [103]	validation_0-rmse:0.16105	validation_1-rmse:0.16169
# [104]	validation_0-rmse:0.16104	validation_1-rmse:0.16170
# [105]	validation_0-rmse:0.16104	validation_1-rmse:0.16171
# [106]	validation_0-rmse:0.16103	validation_1-rmse:0.16172
# R2指数： 0.35866948825616285
